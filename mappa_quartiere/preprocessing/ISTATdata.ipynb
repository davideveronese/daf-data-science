# %% [markdown]
# ## Loading and preprocessing ISTAT data

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
from os import path, listdir

# %%
## Loading ISTAT data
cpaPath = '../data/dati-cpa_2011/Sezioni di Censimento/'
fileList = [f for f in listdir(cpaPath) if f.startswith('R')]
dfList = []
cityList = ['Milano', 'Torino']
dataDict = {}
for filename in fileList:
    regionData = pd.read_csv(path.join(cpaPath, filename), sep=';', encoding='latin').set_index('SEZ2011')
    # extract the councils we are intersted in
    for city in cityList:
        cityData = regionData[regionData.COMUNE==city]
        if cityData.size>0:
            dataDict[city] = cityData

# %%
fieldsMeaning = pd.read_csv(path.join(cpaPath, 'tracciato_2011_sezioni.csv'), sep=';',encoding='latin')
fieldsMeaning
# Out:
#     NOME_CAMPO                                        DEFINIZIONE
# 0       CODREG  Codice numerico che identifica univocamente la...
# 1      REGIONE                        Denominazione della regione
# 2       CODPRO  Codice numerico che identifica univocamente la...
# 3    PROVINCIA                      Denominazione della provincia
# 4       CODCOM  Codice numerico che identifica univocamente il...
# 5       COMUNE                           Denominazione del comune
# 6       PROCOM  Codice numerico che identifica univocamente il...
# 7      SEZ2011  Codice numerico che identifica univocamente la...
# 8         NSEZ  Numero che identifica univocamente la sezione ...
# 9          ACE  Numero che identifica univocamente l'area di c...
# 10      CODLOC  Codice numerico che identifica la località 201...
# 11      CODASC  Codice numerico che identifica univocamente l'...
# 12          P1                     Popolazione residente - totale
# 13          P2                     Popolazione residente - maschi
# 14          P3                    Popolazione residente - femmine
# 15          P4              Popolazione residente - celibi/nubili
# 16          P5  Popolazione residente - coniugati/e (+ separat...
# 17          P6      Popolazione residente - separati/e legalmente
# 18          P7                   Popolazione residente - vedovi/e
# 19          P8               Popolazione residente - divorziati/e
# 20          P9              Popolazione residente - maschi celibi
# 21         P10  Popolazione residente - maschi coniugati o sep...
# 22         P11  Popolazione residente - maschi separati legalm...
# 23         P12              Popolazione residente - maschi vedovi
# 24         P13          Popolazione residente - maschi divorziati
# 25         P14               Popolazione residente - età < 5 anni
# 26         P15             Popolazione residente - età 5 - 9 anni
# 27         P16           Popolazione residente - età 10 - 14 anni
# 28         P17           Popolazione residente - età 15 - 19 anni
# 29         P18           Popolazione residente - età 20 - 24 anni
# ..         ...                                                ...
# 122         E2          Edifici e complessi di edifici utilizzati
# 123         E3                        Edifici ad uso residenziale
# 124         E4  Edifici e complessi di edifici (utilizzati) ad...
# 125         E5   Edifici ad uso residenziale in muratura portante
# 126         E6  Edifici ad uso residenziale in calcestruzzo ar...
# 127         E7  Edifici ad uso residenziale in altro materiale...
# 128         E8  Edifici ad uso residenziale costruiti prima de...
# 129         E9  Edifici ad uso residenziale costruiti dal 1919...
# 130        E10  Edifici ad uso residenziale costruiti dal 1946...
# 131        E11  Edifici ad uso residenziale costruiti dal 1961...
# 132        E12  Edifici ad uso residenziale costruiti dal 1971...
# 133        E13  Edifici ad uso residenziale costruiti dal 1981...
# 134        E14  Edifici ad uso residenziale costruiti dal 1991...
# 135        E15  Edifici ad uso residenziale costruiti dal 2001...
# 136        E16  Edifici ad uso residenziale costruiti dopo il ...
# 137        E17           Edifici ad uso residenziale con un piano
# 138        E18            Edifici ad uso residenziale con 2 piani
# 139        E19            Edifici ad uso residenziale con 3 piani
# 140        E20      Edifici ad uso residenziale con 4 piani o più
# 141        E21         Edifici ad uso residenziale con un interno
# 142        E22          Edifici ad uso residenziale con 2 interni
# 143        E23       Edifici ad uso residenziale da 3 a 4 interni
# 144        E24       Edifici ad uso residenziale da 5 a 8 interni
# 145        E25      Edifici ad uso residenziale da 9 a 15 interni
# 146        E26   Edifici ad uso residenziale con 16 interni o più
# 147        E27      Totale interni in edifici ad uso residenziale
# 148        E28  Edifici ad uso residenziale con stato di conse...
# 149        E29  Edifici ad uso residenziale con stato di conse...
# 150        E30  Edifici ad uso residenziale con stato di conse...
# 151        E31  Edifici ad uso residenziale con stato di conse...
#
# [152 rows x 2 columns]

# %%
# Join sez geofile for Milano
sezNameCol = 'SEZ2011'
shapeDataMilano = gpd.read_file('../data/milanoSezGeo')
print(shapeDataMilano[sezNameCol].isin(dataDict['Milano'].index).mean())
print(dataDict['Milano'].index.isin(shapeDataMilano[sezNameCol]).mean())
joinedData = pd.merge(shapeDataMilano, dataDict['Milano'], how='inner', right_index=True, left_on=sezNameCol)
joinedData.SEZ2011 = joinedData.SEZ2011.astype(int)
# Out:
# 0.9888139496627735
# 0.9990028253282367

# %%
# collect quartiere label
quartiereLabels = pd.read_csv('../data/Milano_sezToQuartieri.csv')
# fix typo
quartiereLabels.NIL.replace(to_replace='MAGENTA - S.VITTORE', value='MAGENTA - S. VITTORE', inplace=True)

quartieriData = gpd.read_file('../data/Milano_quartieri.geojson')
# join
quartiereLabels = quartiereLabels.join(quartieriData[['NIL', 'ID_NIL']].set_index('NIL'), on='NIL')
quartiereLabels = quartiereLabels.set_index(sezNameCol)

assert not any(quartiereLabels.ID_NIL.isnull()), 'Typos in NIL field'

# %%
joinedData = joinedData.join(quartiereLabels, on=sezNameCol)
joinedData = joinedData[~joinedData.ID_NIL.isnull()]
joinedData.ID_NIL = joinedData.ID_NIL.astype(int)
#joinedData.to_csv('test.csv')

# %%
quartiereLabels
# Out:
#                                   NIL  ID_NIL
# SEZ2011
# 151460000001                    DUOMO       1
# 151460000002                    DUOMO       1
# 151460000003                    DUOMO       1
# 151460000004                    DUOMO       1
# 151460000005                    DUOMO       1
# 151460000006                    DUOMO       1
# 151460000007                    DUOMO       1
# 151460000008                    DUOMO       1
# 151460000009                    DUOMO       1
# 151460000010                    DUOMO       1
# 151460000011                    DUOMO       1
# 151460000012                    DUOMO       1
# 151460000013                    DUOMO       1
# 151460000014                    DUOMO       1
# 151460000015                    DUOMO       1
# 151460000016                    DUOMO       1
# 151460000017                    DUOMO       1
# 151460000018                    DUOMO       1
# 151460000019                    DUOMO       1
# 151460000020                    DUOMO       1
# 151460000021                    DUOMO       1
# 151460000022                    DUOMO       1
# 151460000023                    DUOMO       1
# 151460000024                    DUOMO       1
# 151460000025     MAGENTA - S. VITTORE       7
# 151460000026     MAGENTA - S. VITTORE       7
# 151460000027                    DUOMO       1
# 151460000028                    DUOMO       1
# 151460000029                    DUOMO       1
# 151460000030                    DUOMO       1
# ...                               ...     ...
# 151460006078                 MUGGIANO      54
# 151460006079              GIAMBELLINO      49
# 151460006080              GIAMBELLINO      49
# 151460006081              GIAMBELLINO      49
# 151460006082              GIAMBELLINO      49
# 151460006083   RONCHETTO SUL NAVIGLIO      48
# 151460006084   RONCHETTO SUL NAVIGLIO      48
# 151460006085        EX OM - MORIVIONE      37
# 151460006086        EX OM - MORIVIONE      37
# 151460006087        EX OM - MORIVIONE      37
# 151460006088          UMBRIA - MOLISE      28
# 151460006089          UMBRIA - MOLISE      28
# 151460006090                 ROGOREDO      33
# 151460006091                 ROGOREDO      33
# 151460006092                 ROGOREDO      33
# 151460006093                 ROGOREDO      33
# 151460006094                 ROGOREDO      33
# 151460006095                 ROGOREDO      33
# 151460006096                 ROGOREDO      33
# 151460006097                 ROGOREDO      33
# 151460006098                 ROGOREDO      33
# 151460006099                  STADERA      42
# 151460006100                  STADERA      42
# 151460006101                  STADERA      42
# 151460006102                  STADERA      42
# 151460006103                  STADERA      42
# 151460006104                  STADERA      42
# 151460006105  GRATOSOGLIO - TICINELLO      41
# 151460006106  GRATOSOGLIO - TICINELLO      41
# 151460006107  GRATOSOGLIO - TICINELLO      41
#
# [6078 rows x 2 columns]

# %%
# rename columns
joinedData.rename({'NIL':'quartiere', 'ID_NIL': 'IDquartiere'}, axis='columns', inplace=True)

# %%
joinedData.to_file('../final/Milano_sezioni.geojson', driver='GeoJSON')

# %%
zz = gpd.read_file('../final/Milano_sezioni.geojson')

# %%
zz
# Out:
#       OBJECTID  PRO_COM   SEZ  TIPO_LOC     SEZ2011     SHAPE_AREA  \
# 0        49010    15146   236         1  2147483647    8061.468253
# 1        49011    15146   237         1  2147483647    5416.911543
# 2        49015    15146   241         1  2147483647   12107.858114
# 3        49018    15146   244         1  2147483647   11178.703560
# 4        49241    15146   151         1  2147483647    2727.769331
# 5        49253    15146   163         1  2147483647    7925.594736
# 6        50663    15146   257         1  2147483647   12029.853529
# 7        50669    15146   263         1  2147483647    7023.062636
# 8        50675    15146   270         1  2147483647   11837.226655
# 9        51544    15146     3         1  2147483647   10964.756918
# 10       51562    15146    21         1  2147483647   10797.189229
# 11       51600    15146    61         1  2147483647   20812.702647
# 12       51615    15146    76         1  2147483647    3745.420502
# 13       51619    15146    80         1  2147483647    7510.191766
# 14       51692    15146   179         1  2147483647   13180.893969
# 15       51699    15146   187         1  2147483647    7309.734715
# 16       51708    15146   196         1  2147483647   26206.169191
# 17       51714    15146   202         1  2147483647    3680.684574
# 18       51720    15146   208         1  2147483647    3879.197204
# 19       51725    15146   213         1  2147483647    2869.698202
# 20       51747    15146   286         1  2147483647    5070.059039
# 21       49012    15146   238         1  2147483647   12947.700982
# 22       49013    15146   239         1  2147483647    4949.096179
# 23       50673    15146   268         1  2147483647    2509.661277
# 24       51556    15146    15         1  2147483647   17869.878606
# 25       51560    15146    19         1  2147483647    6433.443065
# 26       51563    15146    22         1  2147483647   56344.548709
# 27       51590    15146    50         1  2147483647    6432.195750
# 28       51604    15146    65         1  2147483647   10397.561964
# 29       51662    15146   124         1  2147483647  114468.479252
# ...        ...      ...   ...       ...         ...            ...
# 5980     53968    15146  3039         1  2147483647   40637.004434
# 5981     54037    15146  3117         1  2147483647   66710.156757
# 5982     54038    15146  3118         4  2147483647  256443.718784
# 5983     54670    15146  2739         1  2147483647   45283.591616
# 5984     54681    15146  3038         1  2147483647   77273.308986
# 5985     51225    15146  5129         4  2147483647  207753.298283
# 5986     52522    15146  2837         4  2147483647   52787.245935
# 5987     53952    15146  3011         2  2147483647   39855.587516
# 5988     53953    15146  3012         4  2147483647  280212.771320
# 5989     54602    15146  1875         4  2147483647  253036.313394
# 5990     49269    15146  4244         4  2147483647  978888.005264
# 5991     49297    15146  4450         4  2147483647  338245.366130
# 5992     49301    15146  4460         4  2147483647  345288.327556
# 5993     49305    15146  4467         1  2147483647   20326.425498
# 5994     51529    15146  4456         4  2147483647  541440.348140
# 5995     54688    15146  3237         4  2147483647  146249.051623
# 5996     54562    15146  3041         4  2147483647  487682.021160
# 5997     54171    15146  1273         4  2147483647  235090.510359
# 5998     49273    15146  4249         4  2147483647  659386.897535
# 5999     49299    15146  4453         4  2147483647   78985.832841
# 6000     49308    15146  4470         1  2147483647   63022.634026
# 6001     54036    15146  3115         4  2147483647  477225.154810
# 6002     54039    15146  3119         4  2147483647  331939.808784
# 6003     54679    15146  3028         2  2147483647   44692.912006
# 6004     51226    15146  5131         4  2147483647   85431.777257
# 6005     52483    15146  1877         4  2147483647   97271.000156
# 6006     50205    15146  2740         1  2147483647   94555.790817
# 6007     53969    15146  3040         1  2147483647   70955.960279
# 6008     54706    15146  4248         4  2147483647  453997.589417
# 6009     54523    15146  3116         4  2147483647   80452.288116
#
#         SHAPE_LEN  POP_2010  ACE_x  mappa2  \
# 0      449.226698      70.0    1.0       3
# 1      344.834372     173.0    1.0      12
# 2      510.055011     160.0    1.0      13
# 3      421.080703     105.0    1.0      22
# 4      262.767785       6.0    1.0       1
# 5      380.231112       0.0    1.0       0
# 6      504.172316      40.0    1.0       7
# 7      338.646027     127.0    1.0       8
# 8      939.197794     178.0    1.0      29
# 9      432.517441      22.0    1.0       1
# 10     463.955080     143.0    1.0      11
# 11     660.545643     122.0    1.0      18
# 12     291.371671       7.0    1.0       7
# 13     412.728972      87.0    1.0       9
# 14     500.057523      44.0    1.0      28
# 15     346.103789      44.0    1.0       8
# 16     644.699714     271.0    1.0      28
# 17     246.899233      61.0    1.0       3
# 18     282.803230      74.0    1.0       4
# 19     267.447238       0.0    1.0       0
# 20     302.929267      78.0    1.0      12
# 21     484.235785     258.0    1.0      24
# 22     366.106984      55.0    1.0       5
# 23     205.994053      26.0    1.0       6
# 24     578.230455       4.0    1.0       0
# 25     352.251318      78.0    1.0      15
# 26     958.963933     370.0    1.0      38
# 27     365.517344      11.0    1.0       0
# 28     458.633777      88.0    1.0      10
# 29    1283.800920       0.0    1.0       0
# ...           ...       ...    ...     ...
# 5980   848.560744      42.0    0.0      65
# 5981  1398.609184      30.0    0.0      23
# 5982  2462.950913       0.0    0.0       0
# 5983  1064.993677     427.0    0.0      72
# 5984  1460.522688      44.0    0.0       0
# 5985  2291.502107      14.0    0.0       4
# 5986  1157.154649       3.0    0.0       0
# 5987   842.392118       3.0    0.0       0
# 5988  3025.745474       1.0    0.0       0
# 5989  2634.002585       1.0    0.0       0
# 5990  4511.250600      26.0    0.0       2
# 5991  2485.490594       2.0    0.0       0
# 5992  2643.410420       0.0    0.0       0
# 5993   682.714618      37.0    0.0       1
# 5994  3433.201051       6.0    0.0       0
# 5995  1892.108465      13.0    0.0       6
# 5996  3248.104272       5.0    0.0       0
# 5997  2585.002618     198.0    0.0       0
# 5998  4439.380149      24.0    0.0       0
# 5999  1226.834103       3.0    0.0       0
# 6000  1476.410160     328.0    0.0      75
# 6001  3026.883181     191.0    0.0       2
# 6002  3574.535189      18.0    0.0       1
# 6003   981.625447       9.0    0.0       0
# 6004  1199.673913       1.0    0.0       0
# 6005  1805.990650       6.0    0.0       6
# 6006  1359.197133      32.0    0.0      13
# 6007  1093.804448     554.0    0.0      37
# 6008  2956.929796       0.0    0.0       0
# 6009  1582.846388       1.0    0.0       0
#
#                             ...                          E25  E26  E27  E28  \
# 0                           ...                            2    0   51    5
# 1                           ...                            5    1   74    0
# 2                           ...                            3    1  105   14
# 3                           ...                            1    2   67    6
# 4                           ...                            0    0    3    1
# 5                           ...                            0    0    0    0
# 6                           ...                            2    0   39    6
# 7                           ...                            5    0   70    1
# 8                           ...                            5    2  111    7
# 9                           ...                            0    2   45    2
# 10                          ...                            0    4  150    4
# 11                          ...                            4    3  129    7
# 12                          ...                            0    0    4    0
# 13                          ...                            2    0   64   13
# 14                          ...                            1    0   31    3
# 15                          ...                            0    0   13    3
# 16                          ...                            6    2  164    2
# 17                          ...                            0    1   37    1
# 18                          ...                            2    1   49    3
# 19                          ...                            0    0    0    0
# 20                          ...                            2    3   82    5
# 21                          ...                            6    3  129    5
# 22                          ...                            2    0   43    6
# 23                          ...                            0    1   17    0
# 24                          ...                            0    0    6    1
# 25                          ...                            2    1   54    4
# 26                          ...                            3   10  318    8
# 27                          ...                            0    0    0    0
# 28                          ...                            0    0   38    8
# 29                          ...                            0    0    0    0
# ...                         ...                          ...  ...  ...  ...
# 5980                        ...                            2    1   80   11
# 5981                        ...                            0    0   11    1
# 5982                        ...                            0    0    0    0
# 5983                        ...                            2    6  208    1
# 5984                        ...                            0    0   28    0
# 5985                        ...                            0    0    8    1
# 5986                        ...                            0    0    0    0
# 5987                        ...                            0    0    6    0
# 5988                        ...                            0    0    0    0
# 5989                        ...                            0    0    1    0
# 5990                        ...                            0    0    4    0
# 5991                        ...                            0    0    0    0
# 5992                        ...                            0    0    0    0
# 5993                        ...                            1    0   19    1
# 5994                        ...                            0    0    3    0
# 5995                        ...                            0    0    8    1
# 5996                        ...                            0    0    2    1
# 5997                        ...                            0    1   29    0
# 5998                        ...                            0    0    8    1
# 5999                        ...                            0    0    1    0
# 6000                        ...                            3    1  148   12
# 6001                        ...                            0    0   12    0
# 6002                        ...                            0    0    7    0
# 6003                        ...                            0    0    7    1
# 6004                        ...                            0    0    1    1
# 6005                        ...                            0    0    1    0
# 6006                        ...                            0    0    9    2
# 6007                        ...                            6    5  221   14
# 6008                        ...                            0    0    0    0
# 6009                        ...                            0    0    1    0
#
#      E29  E30 E31                      NIL  ID_NIL  \
# 0      2    0   0                    DUOMO       1
# 1      7    0   0                    DUOMO       1
# 2      0    0   0                    DUOMO       1
# 3      1    0   0                    DUOMO       1
# 4      0    0   0                    DUOMO       1
# 5      0    0   0                    DUOMO       1
# 6      0    0   0                    DUOMO       1
# 7      6    1   0                    DUOMO       1
# 8      3    0   0                    DUOMO       1
# 9      0    0   0                    DUOMO       1
# 10     1    0   0                    DUOMO       1
# 11     4    1   0                    DUOMO       1
# 12     1    0   0                    DUOMO       1
# 13     0    0   0                    DUOMO       1
# 14     1    0   0                    DUOMO       1
# 15     0    0   0                    DUOMO       1
# 16    11    1   0                    DUOMO       1
# 17     0    0   0                    DUOMO       1
# 18     0    0   0                    DUOMO       1
# 19     0    0   0                    DUOMO       1
# 20     0    0   0                    DUOMO       1
# 21     4    1   0                    DUOMO       1
# 22     0    0   0                    DUOMO       1
# 23     1    0   0                    DUOMO       1
# 24     0    0   0                    DUOMO       1
# 25     1    0   0                    DUOMO       1
# 26     9    2   0                    DUOMO       1
# 27     0    0   0                    DUOMO       1
# 28     0    0   0                    DUOMO       1
# 29     0    0   0                    DUOMO       1
# ...   ..  ...  ..                      ...     ...
# 5980   0    6   0     RONCHETTO DELLE RANE      40
# 5981   3    0   0  GRATOSOGLIO - TICINELLO      41
# 5982   0    0   0        PARCO DEI NAVIGLI      86
# 5983   9    4   1              CHIARAVALLE      34
# 5984   5   14   0     RONCHETTO DELLE RANE      40
# 5985   2    0   0       MAGGIORE - MUSOCCO      72
# 5986   0    0   0      PARCO DELLE ABBAZIE      85
# 5987   2    0   0      PARCO DELLE ABBAZIE      85
# 5988   0    0   0      PARCO DELLE ABBAZIE      85
# 5989   1    0   0   PARCO LAMBRO - CIMIANO      18
# 5990   1    0   0       PARCO AGRICOLO SUD      87
# 5991   0    0   0     PARCO BOSCO IN CITT�      88
# 5992   0    0   0                   FIGINO      63
# 5993   3    2   0                   FIGINO      63
# 5994   1    0   0            QUINTO ROMANO      62
# 5995   1    0   0        PARCO DEI NAVIGLI      86
# 5996   0    0   0      PARCO DELLE ABBAZIE      85
# 5997   1    0   0                  ADRIANO      17
# 5998   2    0   0       PARCO AGRICOLO SUD      87
# 5999   1    0   0     PARCO BOSCO IN CITT�      88
# 6000  27    5   0                   FIGINO      63
# 6001  10    0   0  GRATOSOGLIO - TICINELLO      41
# 6002   1    0   0        PARCO DEI NAVIGLI      86
# 6003   2    0   0      PARCO DELLE ABBAZIE      85
# 6004   0    0   0   CASCINA TRIULZA - EXPO      73
# 6005   1    0   0   PARCO LAMBRO - CIMIANO      18
# 6006   1    0   0              CHIARAVALLE      34
# 6007   7    1   0     RONCHETTO DELLE RANE      40
# 6008   0    0   0       PARCO AGRICOLO SUD      87
# 6009   1    0   0  GRATOSOGLIO - TICINELLO      41
#
#                                                geometry
# 0     POLYGON ((1514122.149438965 5034191.777491422,...
# 1     POLYGON ((1514166.339374326 5034198.582483572,...
# 2     POLYGON ((1514365.509413606 5034211.737496569,...
# 3     POLYGON ((1514508.984403429 5034317.407504656,...
# 4     POLYGON ((1515504.809281959 5035162.942410328,...
# 5     POLYGON ((1515423.209294741 5034342.942450254,...
# 6     POLYGON ((1514314.974360594 5034574.617470345,...
# 7     POLYGON ((1513960.469447921 5034610.952478236,...
# 8     POLYGON ((1513671.81441165 5034319.432449303, ...
# 9     POLYGON ((1515049.884268219 5034427.202487691,...
# 10    POLYGON ((1514149.564421316 5034754.742431791,...
# 11    POLYGON ((1515481.62421878 5034712.187438607, ...
# 12    POLYGON ((1515344.389247986 5034475.312399903,...
# 13    POLYGON ((1515255.519305306 5035277.587374453,...
# 14    POLYGON ((1515292.739242602 5034353.402419345,...
# 15    POLYGON ((1514933.469298576 5034276.382448146,...
# 16    POLYGON ((1514697.669300985 5033897.622497333,...
# 17    POLYGON ((1514885.469297409 5033812.777534286,...
# 18    POLYGON ((1514406.349398042 5033858.997480116,...
# 19    POLYGON ((1514725.249287695 5034033.207535928,...
# 20    POLYGON ((1514025.35943711 5034265.022438437, ...
# 21    POLYGON ((1514217.124414636 5034212.357427894,...
# 22    POLYGON ((1514485.309320348 5034219.57248241, ...
# 23    POLYGON ((1513812.414457876 5034707.937413143,...
# 24    POLYGON ((1514279.744389385 5034725.052443688,...
# 25    POLYGON ((1514146.659416446 5034713.957376294,...
# 26    POLYGON ((1513958.229394987 5034961.117403338,...
# 27    POLYGON ((1514980.629276819 5034713.037456922,...
# 28    POLYGON ((1515589.354212508 5034844.812406044,...
# 29    POLYGON ((1514065.029413778 5035482.712336216,...
# ...                                                 ...
# 5980  POLYGON ((1514297.534428706 5027410.938147982,...
# 5981  POLYGON ((1512405.159593352 5027705.673079271,...
# 5982  POLYGON ((1512193.324581397 5029232.347957341,...
# 5983  POLYGON ((1518830.208965911 5029006.298034638,...
# 5984  POLYGON ((1514336.254351099 5027405.928127745,...
# 5985  POLYGON ((1508342.224942772 5040196.326863023,...
# 5986  POLYGON ((1517427.70407405 5028573.133083168, ...
# 5987  POLYGON ((1515160.564309054 5029667.72796826, ...
# 5988  POLYGON ((1514172.554341238 5030298.422851314,...
# 5989  POLYGON ((1520039.65878991 5038718.011983209, ...
# 5990  POLYGON ((1504432.055365378 5033415.527552713,...
# 5991  POLYGON ((1506254.060177098 5035520.51236235, ...
# 5992  POLYGON ((1505233.135289785 5037770.732155355,...
# 5993  POLYGON ((1505837.835277987 5037734.652108319,...
# 5994  POLYGON ((1505919.585250213 5036143.502310051,...
# 5995  POLYGON ((1510978.934709956 5030171.132914751,...
# 5996  POLYGON ((1513614.674411885 5027507.048120355,...
# 5997  POLYGON ((1520503.348725761 5040261.726844009,...
# 5998  POLYGON ((1505988.060199003 5033771.557518933,...
# 5999  POLYGON ((1506207.865169856 5035215.642359052,...
# 6000  POLYGON ((1505805.125230792 5037741.377122529,...
# 6001  POLYGON ((1512486.304589115 5028316.398033489,...
# 6002  POLYGON ((1512766.979518196 5029675.942928824,...
# 6003  POLYGON ((1514438.774396474 5029182.157942044,...
# 6004  POLYGON ((1507476.66003104 5040941.70675079, 1...
# 6005  POLYGON ((1519874.503829865 5038252.287035763,...
# 6006  POLYGON ((1518582.148911178 5029453.997909104,...
# 6007  POLYGON ((1514253.564402289 5027857.273144782,...
# 6008  POLYGON ((1505497.720233631 5033737.537482809,...
# 6009  POLYGON ((1512548.914534348 5027751.943105122,...
#
# [6010 rows x 165 columns]

# %%
# export as csv to final folder
for city, cityData in dataDict.items():
    cityData.to_csv('../final/'+city+'_cpa_2011.csv', sep=';')
